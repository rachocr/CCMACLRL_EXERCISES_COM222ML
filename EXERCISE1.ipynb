# %% [markdown]
# <a href="https://colab.research.google.com/github/rachocr/CCMACLRL_EXERCISES_COM222ML/blob/main/EXERCISE1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EXERCISE 1

# %% [markdown]
# ##Functions

# %%
# !pip install pandas
# !pip install matplotlib

# %%
def mysurname (surname):
  print(surname)

# %%
print("Racho")
# Out:
# Charles

# %%
def fullname (fname, lname):
  print(fname, lname)

# %%
fullname("Charles", "Racho")
# Out:
# Charles Racho

# %%
def completename(*fullname):
  print(fullname)

# %%
completename("Charles", "Angelo", "Racho")
# Out:
# ('Charles', 'Angelo', 'Racho')

# %%
name = "Charles"

lname : str = "Racho"

lname
# Out:
# 'Racho'

# %%
def mynumber(num : int):
  print(num)

# %%
mynumber(5)
# Out:
# 5

# %%
def myletter(letter: str) -> str:
  return letter

# %%
myletter("A")
# Out:
# 'A'

# %% [markdown]
# #Lists

# %%
fruits = ["apple", "banana", "orange", "lemon", "grapes"]

# %%
fruits
# Out:
# ['apple', 'banana', 'orange', 'lemon', 'grapes']

# %%
for i in fruits:
  print(i)
# Out:
# apple
# banana
# orange
# lemon
# grapes

# %%
mynewlist = []

for i in fruits:
  mynewlist.append(i)

# %%
mynewlist
# Out:
# ['apple', 'banana', 'orange', 'lemon', 'grapes']

# %% [markdown]
# ##List Comprehension

# %%
mynewlist = [x for x in fruits]

# %%
mynewlist
# Out:
# ['apple', 'banana', 'orange', 'lemon', 'grapes']

# %%
mynewlist2 = [x for x in fruits if "e" in x]

# %%
mynewlist2
# Out:
# ['apple', 'orange', 'lemon', 'grapes']

# %% [markdown]
# #Map

# %%
mynumbers = [1,2,3,4,5]

# %%
def multiplybytwo(num):
  return num * 2

# %%
mynewnumbers = list(map(multiplybytwo, mynumbers))

# %%
print(mynewnumbers)
# Out:
# [2, 4, 6, 8, 10]

# %% [markdown]
# # Lambda

# %%
answer = lambda x: x * 7
print(answer(5))
# Out:
# 35

# %% [markdown]
# #Pandas

# %%
import pandas as pd

# %%
dataframe = pd.read_excel("data.xlsx")

# %%
dataframe
# Out:
#    Height  Weight  Age
# 0     167      70   20
# 1     160      65   20
# 2     155      43   21
# 3     170      65   25
# 4     160      55   30
# 5     165      70   22
# 6     168      62   35
# 7     175      80   28
# 8     162      58   29
# 9     162      58   29

# %%
dataframe.head()
# Out:
#    Height  Weight  Age
# 0     167      70   20
# 1     160      65   20
# 2     155      43   21
# 3     170      65   25
# 4     160      55   30

# %%
dataframe.tail()
# Out:
#    Height  Weight  Age
# 5     165      70   22
# 6     168      62   35
# 7     175      80   28
# 8     162      58   29
# 9     162      58   29

# %%
dataframe.drop_duplicates(inplace=True)

# %%
dataframe.value_counts()
# Out:
# Height  Weight  Age
# 162     58      29     2
# 155     43      21     1
# 160     55      30     1
#         65      20     1
# 165     70      22     1
# 167     70      20     1
# 168     62      35     1
# 170     65      25     1
# 175     80      28     1
# Name: count, dtype: int64

# %%
dataframe.iloc[0]
# Out:
# Height    167
# Weight     70
# Age        20
# Name: 0, dtype: int64

# %%
dataframe.describe()
# Out:
#            Height     Weight        Age
# count   10.000000  10.000000  10.000000
# mean   164.400000  62.600000  25.900000
# std      5.796551  10.046558   5.087021
# min    155.000000  43.000000  20.000000
# 25%    160.500000  58.000000  21.250000
# 50%    163.500000  63.500000  26.500000
# 75%    167.750000  68.750000  29.000000
# max    175.000000  80.000000  35.000000

# %%
dataframe.shape
# Out:
# (10, 3)

# %%
dataframe.drop(columns='Age')
# Out:
#    Height  Weight
# 0     167      70
# 1     160      65
# 2     155      43
# 3     170      65
# 4     160      55
# 5     165      70
# 6     168      62
# 7     175      80
# 8     162      58
# 9     162      58

# %%
dataframe
# Out:
#    Height  Weight  Age
# 0     167      70   20
# 1     160      65   20
# 2     155      43   21
# 3     170      65   25
# 4     160      55   30
# 5     165      70   22
# 6     168      62   35
# 7     175      80   28
# 8     162      58   29
# 9     162      58   29

# %%
dataframe.drop(columns=["Age"], inplace=True)

# %%
dataframe
# Out:
#    Height  Weight
# 0     167      70
# 1     160      65
# 2     155      43
# 3     170      65
# 4     160      55
# 5     165      70
# 6     168      62
# 7     175      80
# 8     162      58
# 9     162      58

# %% [markdown]
# #matplotlib

# %%
from matplotlib import pyplot as plt

# %%
X1 = [1,2,3,4,5]

# %%
plt.plot(X1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
X2 = [6,7,8,9,10]

plt.plot(X1)
plt.plot(X2)
plt.show()

# %%
Y = [10,11,12,13,14]

plt.plot(X1, Y, marker = 'o', color = 'green', linestyle = 'dotted')
plt.grid()
#plt.grid(axis='x')
plt.show()

# %%
Y = [10,11,12,13,14]

plt.plot(X1, Y, marker = 'o', color = 'green', linestyle = 'dotted')
plt.title("My Plot")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.grid()
#plt.grid(axis='x')
plt.show()

# %%
plt.plot(dataframe['Height'],dataframe['Weight'], marker = 'o', color = 'green', linestyle = 'dotted')
plt.title("My Plot")
plt.xlabel("Height")
plt.ylabel("Weight")
plt.grid()
plt.show()
